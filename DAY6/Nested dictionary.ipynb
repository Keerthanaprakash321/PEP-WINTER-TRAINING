# %% [markdown]
# # Nested dictionary

# %%
car1_model = {'mercedes':1960}
car2_model = {'ferari':1969}
car3_model = {'porche':1958}
car_type = {"car1":car1_model,"car2": car2_model,"car3": car3_model}

print(car_type)
print(car_type['car1'])
print(car_type['car1']['mercedes'])
# Out:
# {'car1': {'mercedes': 1960}, 'car2': {'ferari': 1969}, 'car3': {'porche': 1958}}
# {'mercedes': 1960}
# 1960
