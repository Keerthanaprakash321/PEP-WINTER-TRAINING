# %% [markdown]
# high level python web framework.quick,reliable,fast,stablity
# it provides mutiple pre pluggins.everything is available for web framework like user authentication,routes and views,robust security
# default database:sqlite
# fast,secure,scalable,fully loaded with every feature for web development,versatile
# MTV Framework:
# model-data access layer
# template-presentation layer
# view-business logic layer
