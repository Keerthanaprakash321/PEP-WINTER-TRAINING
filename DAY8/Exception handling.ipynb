# %%
try:
    #code block where exception caj occur
    a=1
    b = "s"
    c =a+b
except nameerror as ex1:
    print("the user have not defined the variable")
except exception as ex:
    print(ex)
    a = b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       4     b = "s"
# ----> 5     c =a+b
#       6 except nameerror as ex1:
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4     b = "s"
#       5     c =a+b
# ----> 6 except nameerror as ex1:
#       7     print("the user have not defined the variable")
#       8 except exception as ex:
#
# NameError: name 'nameerror' is not defined

# %%
try:
    a =int(input("enter the number 1"))
    b=int(input("enter the number 2"))
    c=a/b
    d= a*b
    e=a+b
except NameError:
    print("the user have anor defined the variable")
except ZeroDivisionError:
    print("please enter number greater than zero")
except TypeError:
    print("try to make the dataype similar")
except Exception as ex:
    print(ex)
else:
    print(c)
    print(d)
    print(e)
# Out:
# please enter number greater than zero

# %%
try:
    a =int(input("enter the number 1"))
    b=int(input("enter the number 2"))
    c=a/b
except NameError:
    print("the user have not defined the variable")
except ZeroDivisionError:
    print("please enter number greater than zero")
except TypeError:
    print("try to make the dataype similar")
except Exception as ex:
    print(ex)
else:
    print(c)
finally:
    print("The execution is done")
# Out:
# 0.5227272727272727
# The execution is done

# %%
class Error(Exception):
    pass
class dobException(Exception):
    pass
class customgeneric(Error):
    pass

year=int(input("enter teh year of birth"))
age =2021-year
try:
    if age<=30 and age>20:
        print("he age is valid. you can apply for the exams")
    else:
        raise dobException
except dobException:
    print("the age is not witin the range. you cannot apply for the exams")
# Out:
# he age is valid. you can apply for the exams
