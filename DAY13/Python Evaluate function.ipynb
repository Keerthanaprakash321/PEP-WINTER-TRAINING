# %% [markdown]
# how it works
# 1.parse python expression
# 2.compile into s byte code
# 3.evaluste the python expression
# 4.it will return the result

# %%
var = compile("5+5","<string>","eval")
eval(var)
# Out:
# 10

# %%
x=10
eval("x+50+x**2",{"x":x})
# Out:
# 160

# %%
eval("a+b+c",{},("a":100,"b":200,"c":300)
# Out:
#   Cell In[6], line 1
#     eval("a+b+c",{},("a":100,"b":200,"c":300)
#                         ^
# SyntaxError: invalid syntax
