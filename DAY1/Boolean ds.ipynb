# %%
print(my_str.isalnum())
print(my_str.isalpha())
print(my_str.isdigit())
print(my_str.istitle())
print(my_str.isupper())
print(my_str.islower())
print(my_str.isspace())
print(my_str.endswith('k'))
print(my_str.startswith('k'))

# %%
str = input()
print(str.isdigit())
# Out:
# False

# %% [markdown]
# ## insert

# %%
#insert
ls = ["2"]
ls.insert(2,"naaij")
print(ls)
# Out:
# ['2', 'naaij']

# %%
numbers = [10, 20, 40, 50]

numbers.insert(2, 30)  
print(numbers)
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
# ## extend method

# %%
lst = [1,2,3,4,5,6]
lst.extend([8,9])
print(lst)
# Out:
# [1, 2, 3, 4, 5, 6, 8, 9]

# %%
list = ['apple','banana','orange','kiwi','cherry']
list.extend(['mango','jackfruit'])
print(list)
# Out:
# ['apple', 'banana', 'orange', 'kiwi', 'cherry', 'mango', 'jackfruit']

# %% [markdown]
# ## pop() method

# %%
lst = [1,2,3,4,5,6]
lst.pop()
print(lst)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ## count()

# %% [markdown]
# calculates total occurance of given element of list

# %%
lst = [1,2,34,5,554]
lst.count(1)
print(lst)
# Out:
# [1, 2, 34, 5, 554]

# %% [markdown]
# ## index

# %% [markdown]
# len(lst) calculates total length of the list
# index returns the index of thr firssts occurence.strat and end index are not necessary parameters

# %%
lst = [2,34,56,56,1,2,3]
lst.index(2)
print(lst)
# Out:
# [2, 34, 56, 56, 1, 2, 3]
