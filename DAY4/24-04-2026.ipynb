# %%
#find runner up score.you are give scores.store them in a list and find the score of the runner up.
#inoutb informat: the first ine contains  tottal no of conrtestants a. 
# the second line contains an array of integers each seperated by a space.
#constarints: 2<=a <=100
#o/p format: print the runner up scoe.
#sample input 0:
#5
#23665
#sample output 0
#5
a = int(input())
b = list(map(int, input().split()))
h = max(b)
for i range(b.count(h)):
    b.remove(h)
runner_up = max(b)
print(runner_up)
# Out:
#   Cell In[3], line 14
#     for i range(b.count(h)):
#           ^
# SyntaxError: invalid syntax

# %%
#str = "abcdefgh"
#output = "abcxefgh"
str = input("enter the string")
c = input("which character you want to replace")
r = input("which value it should be replaced string")
a = str.replace(c,r)
print(a)
# Out:
# abdfgghh

# %%
#create a string.and the output should be all the repeated characters which should be stored in a list
str = input()
r = []
for c in str:
    if str.count(c) > 1 and c not in r:
        r.append(c)
print(r)
# Out:
# ['h', 'e']

# %%
input: this is something you should not take care of 
character to find : "h"
limmmit within the string(sub-string)=5
output"true/false"
