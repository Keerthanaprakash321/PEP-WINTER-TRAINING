# %%
'''
three conditions to identify leap year:
the year can be evenly divided by 4, is a leap yera unless:
the year can be evenly divided by 100,it is not a leap year, unless:
the year is also evenly divided by 400. then it us a leap year.
this means in georgian calender, the years 2000 and 2400 are leap years and 1900,2100,2200,2300 and 2500 are not leap years

'''
def is_leap(year):
    leap = False
    if year%4 == 0:
        print("True")
    elif year%100 == 0:
        print("False")
    elif year%400 == 0:
        print("True")
    else:
        print("enter the correct year")
    return leap
year = int(input())
print(is_leap(year))
# Out:
# True
# False
